# %% [markdown]
# ## ESTADISTICAS DE UN TEXTO

# %% [markdown]
# ##### Se realizaran las siguientes operaciones en el texto almacenado en la variable text

# %%
text = """Beautiful is better than ugly.
    Explicit is better than implicit.
    Simple is better than complex.
    Complex is better than complicated.
    Flat is better than nested.
    Sparse is better than dense.
    Readability counts.
    Special cases aren't special enough to break the rules.
    Although practicality beats purity.
    Errors should never pass silently.
    Unless explicitly silenced.
    In the face of ambiguity, refuse the temptation to guess.
    There should be one-- and preferably only one --obvious way
    to do it.
    Although that way may not be obvious at first unless you're
    Dutch.
    Now is better than never.
    Although never is often better than *right* now.
    If the implementation is hard to explain, it's a bad idea.
    If the implementation is easy to explain, it may be a good
    idea.
    Namespaces are one honking great idea -- let's do more of
    those!"""

# %% [markdown]
# • La cantidad total de líneas.

# %%
from src.uno_funciones import cant_lines

cant = cant_lines(text)
print(f"La cantidad de lineas que contiene el texto es en total --> {cant}")
# Out:
# La cantidad de lineas que contiene el texto es en total --> 19

# %% [markdown]
# • La cantidad total de palabras.

# %%
from src.uno_funciones import cant_palabras

cant = cant_palabras(text)
print(f"La cantidad de palabras que contiene el texto es --> {cant}")
# Out:
# La cantidad de palabras que contiene el texto es --> 137

# %% [markdown]
# • El promedio de palabras por línea.

# %%
from src.uno_funciones import promedio_palabras_linea  

promedio = promedio_palabras_linea(text)
print(f"El promedio de palabras por linea es --> {promedio:.2f}")
# Out:
# El promedio de palabras por linea es --> 7.21

# %% [markdown]
# • Todas las líneas cuya cantidad de palabras esté por encima del promedio.

# %%
from src.uno_funciones import lineas_encima_promedio

lineas_encima_promedio(text)
# Out:
# "Las lineas cuyas cantidad de palabras esta por encima del promedio son:\n    Special cases aren't special enough to break the rules (9)\n\n    In the face of ambiguity, refuse the temptation to guess (10)\n\n    There should be one-- and preferably only one --obvious way\n    to do it (13)\n\n    Although that way may not be obvious at first unless you're\n    Dutch (12)\n\n    Although never is often better than *right* now (8)\n\n    If the implementation is hard to explain, it's a bad idea (11)\n\n    If the implementation is easy to explain, it may be a good\n    idea (13)\n\n    Namespaces are one honking great idea -- let's do more of\n    those! (12)\n"
